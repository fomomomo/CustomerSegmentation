# %% [markdown]
# #### Loading Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import sigmoid_kernel
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Reading data

# %%
df = pd.read_csv("D:/Minor Project/data.csv", encoding="ISO-8859-1")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.dropna(subset=['Description'],how='all',inplace=True)

# %%
df.Description[0]
# Out:
# 'WHITE HANGING HEART T-LIGHT HOLDER'

# %% [markdown]
# ## <font color='grey'> Keyword Matching to select top products using similarities in description </font>

# %%
tfv = TfidfVectorizer(max_features=None,
                     strip_accents='unicode',
                     analyzer='word',
                     min_df=10,
                     token_pattern=r'\w{1,}',
                     ngram_range=(1,3), #take the combination of 1-3 different kind of words
                     stop_words='english') #removes all the unnecessary characters like the,in etc.
df['Description'] = df['Description'].fillna('')

# %%
products = df.groupby(['Description'], as_index=False)['InvoiceDate'].max()

# %%
products
# Out:
#                          Description       InvoiceDate
# 0      4 PURPLE FLOCK DINNER CANDLES    9/7/2011 14:09
# 1      50'S CHRISTMAS GIFT BAG LARGE     9/8/2011 8:56
# 2                  DOLLY GIRL BEAKER    9/9/2011 15:09
# 3        I LOVE LONDON MINI BACKPACK   9/30/2011 16:42
# 4        I LOVE LONDON MINI RUCKSACK    10/6/2011 9:11
# ...                              ...               ...
# 4218     wrongly marked carton 22804  11/10/2011 18:20
# 4219    wrongly marked. 23343 in box   7/14/2011 14:27
# 4220    wrongly sold (22719) barcode   3/11/2011 16:25
# 4221            wrongly sold as sets    3/8/2011 17:23
# 4222               wrongly sold sets    3/8/2011 17:29
#
# [4223 rows x 2 columns]

# %%
products
# Out:
#                          Description       InvoiceDate
# 0      4 PURPLE FLOCK DINNER CANDLES    9/7/2011 14:09
# 1      50'S CHRISTMAS GIFT BAG LARGE     9/8/2011 8:56
# 2                  DOLLY GIRL BEAKER    9/9/2011 15:09
# 3        I LOVE LONDON MINI BACKPACK   9/30/2011 16:42
# 4        I LOVE LONDON MINI RUCKSACK    10/6/2011 9:11
# ...                              ...               ...
# 4218     wrongly marked carton 22804  11/10/2011 18:20
# 4219    wrongly marked. 23343 in box   7/14/2011 14:27
# 4220    wrongly sold (22719) barcode   3/11/2011 16:25
# 4221            wrongly sold as sets    3/8/2011 17:23
# 4222               wrongly sold sets    3/8/2011 17:29
#
# [4223 rows x 2 columns]

# %%
#fitting the description column.
tfv_matrix = tfv.fit_transform(products['Description']) #converting everythinng to sparse matrix.

# %%
tfv_matrix
# Out:
# <4223x497 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15311 stored elements in Compressed Sparse Row format>

# %%
tfv_matrix.shape
# Out:
# (4223, 497)

# %%
sig = sigmoid_kernel(tfv_matrix,tfv_matrix) #how description of first product is related to first product and so on.

# %%
sig[0]
# Out:
# array([0.76243788, 0.76159416, 0.76159416, ..., 0.76159416, 0.76159416,
#        0.76159416])

# %%
indices = pd.Series(products.index,index=products['Description']).drop_duplicates()

# %%
    def keywords_matcher(title,sig=sig):
        indx = indices[title]

        #getting pairwise similarity scores
        sig_scores = list(enumerate(sig[indx]))

        #sorting products
        sig_scores = sorted(sig_scores, key=lambda x: x[1], reverse=True)

        #10 most similar products score
        sig_scores = sig_scores[1:100]

        #product indexes
        product_indices = [i[0] for i in sig_scores]

        #Top 10 most similar products
        return products['Description'].iloc[product_indices]

# %%
list(keywords_matcher('4 BLUE DINNER CANDLES SILVER FLOCK', sig=sig).unique())
# Out:
# ['4 IVORY DINNER CANDLES SILVER FLOCK',
#  '4 SKY BLUE DINNER CANDLES',
#  ' 4 PURPLE FLOCK DINNER CANDLES',
#  '4 PINK DINNER CANDLE SILVER FLOCK',
#  '4 BURGUNDY WINE DINNER CANDLES',
#  '4 ROSE PINK DINNER CANDLES',
#  '4 LILY  BOTANICAL DINNER CANDLES',
#  '4 PEAR BOTANICAL DINNER CANDLES',
#  '4 LAVENDER BOTANICAL DINNER CANDLES',
#  '4 PINK FLOCK CHRISTMAS BALLS',
#  'BLUE FLOCK GLASS CANDLEHOLDER',
#  'PINK PILLAR CANDLE SILVER FLOCK',
#  'S/4 CACTI CANDLES',
#  '4 GOLD FLOCK CHRISTMAS BALLS',
#  'IVORY PILLAR CANDLE SILVER FLOCK',
#  '4 WILDFLOWER BOTANICAL CANDLES',
#  'SET/4 BLUE FLOWER CANDLES IN BOWL',
#  'SET/4 GARDEN ROSE DINNER CANDLE',
#  'SILVER  CANDLEPOT JARDIN ',
#  'SILVER FISHING GNOME ',
#  'SILVER LARIAT 40CM',
#  'SILVER ROCCOCO CHANDELIER',
#  'SILVER STANDING GNOME   ',
#  'SILVER TEDDY BEAR',
#  'CUBIC MUG FLOCK BLUE ON BROWN',
#  'TV DINNER TRAY AIR HOSTESS ',
#  '4 VANILLA BOTANICAL CANDLES',
#  'PINK FLOCK GLASS CANDLEHOLDER',
#  'PINK CHRISTMAS FLOCK DROPLET ',
#  'BLUE FLOCK CUSHION COVER ',
#  'SET OF 4 ROSE BOTANICAL CANDLES',
#  'METAL BASE FOR CANDLES',
#  '3 GARDENIA MORRIS BOXED CANDLES',
#  'WHITE CHRISTMAS FLOCK DROPLET ',
#  'WRAP  PINK FLOCK',
#  'MIDNIGHT BLUE GLASS/SILVER BRACELET',
#  'BLACK CHRISTMAS FLOCK DROPLET ',
#  'CONDIMENT TRAY 4 BOWLS AND 4 SPOONS',
#  'S/4 PINK FLOWER CANDLES IN BOWL',
#  'BLUE NEW BAROQUE FLOCK CANDLESTICK',
#  'LIGHT PINK FLOCK GLASS CANDLEHOLDER',
#  'BLUE  VOILE LAMPSHADE',
#  'BLUE CALCULATOR RULER',
#  'BLUE CRUSOE CHECK LAMPSHADE',
#  'BLUE DRAGONFLY HELICOPTER',
#  'BLUE FLY SWAT',
#  'BLUE FLYING SINGING CANARY',
#  'BLUE HOLE PUNCH',
#  'BLUE PUDDING SPOON',
#  'BLUE SHARK HELICOPTER',
#  'RECYCLED ACAPULCO MAT BLUE',
#  'SILICON CUBE 25W, BLUE',
#  'SPACEBOY TV DINNER TRAY',
#  'DOORMAT BLACK FLOCK ',
#  '3 WHITE CHOC MORRIS BOXED CANDLES',
#  'METAL SIGN HER DINNER IS SERVED ',
#  'METAL SIGN HIS DINNER IS SERVED',
#  '3 ROSE MORRIS BOXED CANDLES',
#  'TV DINNER TRAY VINTAGE PAISLEY',
#  'SILVER APERITIF GLASS',
#  'BAG OF SILVER STONES',
#  'SKULL DESIGN TV DINNER TRAY',
#  'SMALL HAMMERED SILVER CANDLEPOT ',
#  'SMALL REGAL  SILVER CANDLEPOT ',
#  'SMALL SILVER TRELLIS CANDLEPOT',
#  'IVORY PILLAR CANDLE GOLD FLOCK',
#  'ENAMEL DINNER PLATE PANTRY',
#  'SILVER ROCOCO CANDLE STICK',
#  'CUBIC MUG FLOCK PINK ON BROWN',
#  'BOX OF 9 PEBBLE CANDLES',
#  'CUPID DESIGN SCENTED CANDLES',
#  'SET 6 FOOTBALL CELEBRATION CANDLES',
#  'SET OF 6 GIRLS CELEBRATION CANDLES',
#  'OPULENT VELVET SET/3 CANDLES',
#  'SET/10 BLUE POLKADOT PARTY CANDLES',
#  'CACTI T-LIGHT CANDLES',
#  'HYACINTH BULB T-LIGHT CANDLES',
#  'SET 8 CANDLES VINTAGE DOILEY',
#  'PINK FLOCK SUEDE CUSHION COVER ',
#  'SILVER FABRIC MIRROR',
#  'SILVER LOOKING MIRROR',
#  'VINYL RECORD FRAME SILVER',
#  'TV DINNER TRAY DOLLY GIRL',
#  'SET OF 12 FORK CANDLES',
#  'SET/12 TAPER CANDLES',
#  'PINK FLOCK PHOTO FRAME ',
#  'SET/3 CHRISTMAS DECOUPAGE CANDLES',
#  'HOMEMADE JAM SCENTED CANDLES',
#  'SET OF 4 CAROUSEL PLACEMATS ',
#  'SET OF 4 SANTA PLACE SETTINGS',
#  'SET/4 BADGES BEETLES',
#  'SET/4 BADGES CUTE CREATURES',
#  'SET/4 BADGES DOGS',
#  'SET/4 COLOURFUL MIXING BOWLS',
#  'EMPIRE UNION JACK TV DINNER TRAY',
#  '4 TRADITIONAL SPINNING TOPS',
#  'PINK NEW BAROQUE FLOCK CANDLESTICK',
#  'PINK BAROQUE FLOCK CANDLE HOLDER',
#  'SILVER DISCO HANDBAG']

# %%
n=input("Enter the name of the product: ")
print("\nTop matched products are: \n")
print(keywords_matcher(n, sig=sig).unique())
# Out:
# Enter the name of the product:  4 PURPLE FLOCK DINNER CANDLES
#
# Top matched products are:
#
# ['4 BLUE DINNER CANDLES SILVER FLOCK'
#  '4 IVORY DINNER CANDLES SILVER FLOCK' '4 BURGUNDY WINE DINNER CANDLES'
#  '4 SKY BLUE DINNER CANDLES' '4 ROSE PINK DINNER CANDLES'
#  '4 LILY  BOTANICAL DINNER CANDLES' '4 PEAR BOTANICAL DINNER CANDLES'
#  '4 PINK DINNER CANDLE SILVER FLOCK' '4 LAVENDER BOTANICAL DINNER CANDLES'
#  '4 PINK FLOCK CHRISTMAS BALLS' 'S/4 CACTI CANDLES'
#  '4 GOLD FLOCK CHRISTMAS BALLS' 'PURPLE FRANGIPANI HAIRCLIP'
#  '4 WILDFLOWER BOTANICAL CANDLES' 'SET/4 GARDEN ROSE DINNER CANDLE'
#  'TV DINNER TRAY AIR HOSTESS ' '4 VANILLA BOTANICAL CANDLES'
#  'PINK FLOCK GLASS CANDLEHOLDER' 'PINK CHRISTMAS FLOCK DROPLET '
#  'BLUE FLOCK GLASS CANDLEHOLDER' 'PURPLE ANEMONE ARTIFICIAL FLOWER'
#  'PURPLE FOXGLOVE ARTIIFCIAL FLOWER' 'UBO-LIGHT TRIOBASE PURPLE'
#  'SET/4 BLUE FLOWER CANDLES IN BOWL' 'SET OF 4 ROSE BOTANICAL CANDLES'
#  'METAL BASE FOR CANDLES' '3 GARDENIA MORRIS BOXED CANDLES'
#  'PURPLE FRANGIPANI NECKLACE' 'PURPLE GEMSTONE NECKLACE 45CM'
#  'PURPLE/COPPER HANGING LAMPSHADE' 'WHITE CHRISTMAS FLOCK DROPLET '
#  'WRAP  PINK FLOCK' 'BLACK CHRISTMAS FLOCK DROPLET '
#  'PURPLE GEMSTONE BRACELET' 'CONDIMENT TRAY 4 BOWLS AND 4 SPOONS'
#  'S/4 PINK FLOWER CANDLES IN BOWL' 'LIGHT PINK FLOCK GLASS CANDLEHOLDER'
#  'SPACEBOY TV DINNER TRAY' 'PINK PILLAR CANDLE SILVER FLOCK'
#  'DOORMAT BLACK FLOCK ' 'PURPLE ACRYLIC FACETED BANGLE'
#  '3 WHITE CHOC MORRIS BOXED CANDLES' 'PURPLE VINTAGE EARRINGS'
#  'METAL SIGN HER DINNER IS SERVED ' 'METAL SIGN HIS DINNER IS SERVED'
#  '3 ROSE MORRIS BOXED CANDLES' 'TV DINNER TRAY VINTAGE PAISLEY'
#  'IVORY PILLAR CANDLE SILVER FLOCK' 'PINK/PURPLE RETRO RADIO'
#  'FELTCRAFT HAIRBAND PINK AND PURPLE' 'FLOWER PURPLE CLOCK WITH SUCKER'
#  'SKULL DESIGN TV DINNER TRAY' 'DIAMANTE NECKLACE PURPLE'
#  'IVORY PILLAR CANDLE GOLD FLOCK' 'ENAMEL DINNER PLATE PANTRY'
#  'CUBIC MUG FLOCK PINK ON BROWN' 'PURPLE SWEETHEART BRACELET'
#  'CUBIC MUG FLOCK BLUE ON BROWN' 'PURPLE LAS VEGAS BRACELET ROUND'
#  'PINK/PURPLE CIRCLE CURTAIN' 'BOX OF 9 PEBBLE CANDLES'
#  'CUPID DESIGN SCENTED CANDLES' 'SET 6 FOOTBALL CELEBRATION CANDLES'
#  'SET OF 6 GIRLS CELEBRATION CANDLES' 'OPULENT VELVET SET/3 CANDLES'
#  'ROUND PURPLE CLOCK WITH SUCKER' 'CACTI T-LIGHT CANDLES'
#  'HYACINTH BULB T-LIGHT CANDLES' 'SET 8 CANDLES VINTAGE DOILEY'
#  'PURPLE PAPER PARASOL' 'PINK FLOCK SUEDE CUSHION COVER '
#  'BLUE FLOCK CUSHION COVER ' 'TV DINNER TRAY DOLLY GIRL'
#  'SET OF 12 FORK CANDLES' 'SET/12 TAPER CANDLES' 'PINK FLOCK PHOTO FRAME '
#  'FLOWER PURPLE CLOCK W/SUCKER' 'PURPLE/TURQ FLOWERS HANDBAG'
#  'PURPLE DRESS JEWELLERY STAND' 'PURPLE ENAMEL FLOWER RING'
#  'SET/3 CHRISTMAS DECOUPAGE CANDLES' 'HOMEMADE JAM SCENTED CANDLES'
#  'SET OF 4 CAROUSEL PLACEMATS ' 'SET OF 4 SANTA PLACE SETTINGS'
#  'SET/4 BADGES BEETLES' 'SET/4 BADGES CUTE CREATURES' 'SET/4 BADGES DOGS'
#  'SET/4 COLOURFUL MIXING BOWLS' 'PURPLE DRAWERKNOB ACRYLIC EDWARDIAN'
#  'PURPLE ENAMEL+GLASS HAIR COMB' 'EMPIRE UNION JACK TV DINNER TRAY'
#  'PURPLE ENAMEL FLOWER HAIR TIE' '4 TRADITIONAL SPINNING TOPS'
#  'DROP DIAMANTE EARRINGS PURPLE' 'PURPLE BOUDICCA LARGE BRACELET'
#  'SMALL PURPLE BABUSHKA NOTEBOOK ' 'LARGE PURPLE BABUSHKA NOTEBOOK  '
#  'PINK NEW BAROQUE FLOCK CANDLESTICK' 'PINK BAROQUE FLOCK CANDLE HOLDER']

# %%
# np.savetxt('CosinSimilarity.txt', sig)

# %%
df[df.Description.isin(list(keywords_matcher('4 BLUE DINNER CANDLES SILVER FLOCK', sig=sig).unique()))]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 192       536388     22969        HOMEMADE JAM SCENTED CANDLES        12
# 233       536390     22969        HOMEMADE JAM SCENTED CANDLES        96
# 317       536400     22969        HOMEMADE JAM SCENTED CANDLES        12
# 329       536401     22473      TV DINNER TRAY VINTAGE PAISLEY         1
# 336       536401     20820               SILVER LOOKING MIRROR         3
# ...          ...       ...                                 ...       ...
# 541539    581498     85174                   S/4 CACTI CANDLES         1
# 541618    581516     21620     SET OF 4 ROSE BOTANICAL CANDLES        12
# 541636    581538     21222                SET/4 BADGES BEETLES         1
# 541637    581538     21220                   SET/4 BADGES DOGS         1
# 541769    581578     21124  SET/10 BLUE POLKADOT PARTY CANDLES        24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 192      12/1/2010 9:59       1.45     16250.0  United Kingdom
# 233     12/1/2010 10:19       1.25     17511.0  United Kingdom
# 317     12/1/2010 10:53       1.45     13448.0  United Kingdom
# 329     12/1/2010 11:21       4.95     15862.0  United Kingdom
# 336     12/1/2010 11:21       4.95     15862.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541539  12/9/2011 10:26      10.79         NaN  United Kingdom
# 541618  12/9/2011 11:26       1.25     14422.0  United Kingdom
# 541636  12/9/2011 11:34       1.25     14446.0  United Kingdom
# 541637  12/9/2011 11:34       1.25     14446.0  United Kingdom
# 541769  12/9/2011 12:16       1.25     12713.0         Germany
#
# [7097 rows x 8 columns]

# %%
df[df.Description.isin(['WHITE HANGING HEART T-LIGHT HOLDER'])]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 0         536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 49        536373    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 66        536375    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 220       536390    85123A  WHITE HANGING HEART T-LIGHT HOLDER        64
# 262       536394    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# ...          ...       ...                                 ...       ...
# 537291    581246    85123A  WHITE HANGING HEART T-LIGHT HOLDER         1
# 537326    581253    85123A  WHITE HANGING HEART T-LIGHT HOLDER         2
# 537852    581356    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 539979    581452    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# 540217    581472    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 49       12/1/2010 9:02       2.55     17850.0  United Kingdom
# 66       12/1/2010 9:32       2.55     17850.0  United Kingdom
# 220     12/1/2010 10:19       2.55     17511.0  United Kingdom
# 262     12/1/2010 10:39       2.55     13408.0  United Kingdom
# ...                 ...        ...         ...             ...
# 537291  12/8/2011 10:59       2.95     15453.0  United Kingdom
# 537326  12/8/2011 11:15       2.95     16891.0  United Kingdom
# 537852  12/8/2011 12:28       2.95     17830.0  United Kingdom
# 539979  12/8/2011 18:03       2.55     17675.0  United Kingdom
# 540217  12/8/2011 19:55       2.95     15796.0  United Kingdom
#
# [2369 rows x 8 columns]
